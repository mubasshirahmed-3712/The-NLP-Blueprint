# %% [markdown]
# <h2 style="text-align:center;">📖 Lemmatization in NLP</h2>
#
# ---
#
# ### 🔹 What is Lemmatization?
# Lemmatization reduces words to their **dictionary/base form (lemma)** using vocabulary + grammar rules.
#
# 👉 Example:
# - "studies" → "study"
# - "better" → "good"
#
# ---
#
# ### 🔹 Why Better than Stemming?
# - Produces meaningful root words.
# - Considers grammar (noun, verb forms).
#
# ---

# %%
# ➤ Import libraries
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# nltk.download("wordnet")
# nltk.download("omw-1.4")

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()

# Sample words
words = ["playing", "studies", "better", "cars"]

print("Word → Lemma (noun)")
for w in words:
    print(w, "→", lemmatizer.lemmatize(w, pos="n"))

print("\nWord → Lemma (verb)")
for w in words:
    print(w, "→", lemmatizer.lemmatize(w, pos="v"))
# Out:
# Word → Lemma (noun)
# playing → playing
# studies → study
# better → better
# cars → car
#
# Word → Lemma (verb)
# playing → play
# studies → study
# better → better
# cars → cars

# %% [markdown]
# ---
#
# ### ✅ Summary
# - **Lemmatization** is smarter than stemming.
# - Uses dictionary + grammar → meaningful words.
# - Example: "better" → "good".
#
# Next Notebook ➡ **POS Tagging**
#
# ---
